# %%
import torch
import torch.nn as nn
import transformers_preprocess as data_preprocess
import pickle
from metrics import *
from torch import Tensor
import math
import numpy as np
from torch.nn import Transformer

# %%
device = torch.device("cpu")

# %%
class PositionalEncoding(nn.Module):
    def __init__(self,
                 emb_size: int,
                 dropout: float,
                 maxlen: int = 5000):
        super(PositionalEncoding, self).__init__()
        den = torch.exp(- torch.arange(0, emb_size, 2)* math.log(10000) / emb_size)
        pos = torch.arange(0, maxlen).reshape(maxlen, 1)
        pos_embedding = torch.zeros((maxlen, emb_size))
        pos_embedding[:, 0::2] = torch.sin(pos * den)
        pos_embedding[:, 1::2] = torch.cos(pos * den)
        pos_embedding = pos_embedding.unsqueeze(-2)

        self.dropout = nn.Dropout(dropout)
        self.register_buffer('pos_embedding', pos_embedding)

    def forward(self, token_embedding: Tensor):
        return self.dropout(token_embedding + self.pos_embedding[:token_embedding.size(0), :])

# helper Module to convert tensor of input indices into corresponding tensor of token embeddings
class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size: int, emb_size):
        super(TokenEmbedding, self).__init__()
        self.embedding = nn.Embedding(vocab_size, emb_size)
        self.emb_size = emb_size

    def forward(self, tokens: Tensor):
        return self.embedding(tokens.long()) * math.sqrt(self.emb_size)


class Seq2SeqTransformer(nn.Module):
    def __init__(self,
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 emb_size: int,
                 nhead: int,
                 src_vocab_size: int,
                 tgt_vocab_size: int,
                 dim_feedforward: int = 512,
                 dropout: float = 0.1):
        super(Seq2SeqTransformer, self).__init__()
        self.transformer = Transformer(d_model=emb_size,
                                       nhead=nhead,
                                       num_encoder_layers=num_encoder_layers,
                                       num_decoder_layers=num_decoder_layers,
                                       dim_feedforward=dim_feedforward,
                                       dropout=dropout)

        self.generator = nn.Linear(emb_size, tgt_vocab_size)
        self.src_tok_emb = TokenEmbedding(src_vocab_size, emb_size)
        self.tgt_tok_emb = TokenEmbedding(tgt_vocab_size, emb_size)
        self.positional_encoding = PositionalEncoding(
            emb_size, dropout=dropout)

    def forward(self,
                src: Tensor,
                trg: Tensor,
                src_mask: Tensor,
                tgt_mask: Tensor,
                src_padding_mask: Tensor,
                tgt_padding_mask: Tensor,
                memory_key_padding_mask: Tensor):
        src_emb = self.positional_encoding(self.src_tok_emb(src))
        tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))
        outs = self.transformer(src_emb, tgt_emb, src_mask, tgt_mask, None,
                                src_padding_mask, tgt_padding_mask, memory_key_padding_mask)
        return self.generator(outs)

    def encode(self, src: Tensor, src_mask: Tensor):
        return self.transformer.encoder(self.positional_encoding(
                            self.src_tok_emb(src)), src_mask)

    def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
        return self.transformer.decoder(self.positional_encoding(
                          self.tgt_tok_emb(tgt)), memory,
                          tgt_mask)

# %%
class Trainer():
    
    def __init__(self,config_dict,device) -> None:

        self.config_dict = config_dict
        self.hidden_size = config_dict['hidden_size']
        self.batch_size = config_dict['batch_size']
        self.from_lang_str = config_dict['from_lang']
        self.max_length = config_dict['max_sentence_length']
        self.convert_eng_to_lang = config_dict['convert_eng_to_lang']

        self.use_pkl_data = config_dict['use_pkl_data']

        self.indx_sent_func = data_preprocess.indexesFromSentence
        self.optimizer = None

        self.device = device

        self.epoch_count = config_dict['epoch_count']
        self.learning_rate = config_dict['learning_rate']

        import pprint
        pprint.pprint(config_dict)

        in_lang_name = "eng" if self.convert_eng_to_lang else self.from_lang_str
        out_lang_name = self.from_lang_str if self.convert_eng_to_lang else "eng"

        save_str = f"{in_lang_name}_to_{out_lang_name}.pkl"

        with open(save_str, 'rb') as f:
            loads = pickle.load(f)


        self.in_lang = loads['input_lang']
        self.out_lang = loads['output_lang']
        self.in_ids = loads['test_input_ids']
        self.tgt_ids = loads['test_target_ids']
        self.pairs = loads['test_pairs']
        self.SOS_token = loads['SOS_token']
        self.EOS_token = loads['EOS_token']
        self.attention_flag = config_dict['use_attention']

        self.metrics = [CosineSimilarity(1),BLEUScore(1),METEORScore(1),ROUGEScore_custom(1)]

        SRC_VOCAB_SIZE = self.in_lang.n_words
        TGT_VOCAB_SIZE = self.out_lang.n_words
        EMB_SIZE = 512
        NHEAD = 8
        FFN_HID_DIM = 512
        NUM_ENCODER_LAYERS = 3
        NUM_DECODER_LAYERS = 3

        self.transformer = Seq2SeqTransformer(NUM_ENCODER_LAYERS, NUM_DECODER_LAYERS, EMB_SIZE,
                                 NHEAD, SRC_VOCAB_SIZE, TGT_VOCAB_SIZE, FFN_HID_DIM).to(device)
        
        self.transformer.load_state_dict(torch.load('tf_models/fra_to_eng_tf.pth'))
        

    def generate_square_subsequent_mask(self,sz):
        mask = (torch.triu(torch.ones((sz, sz), device=device)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    
    def greedy_decode(self, model, fsrc, fsrc_masks,fends, start_symbol):
        outputs = []
        for i in range(len(fsrc)):
            src = fsrc[i].unsqueeze(1).to(self.device)
            src_mask = fsrc_masks[i].to(self.device)
            memory = model.encode(src, src_mask)
            ys = torch.ones(1, 1).fill_(start_symbol).type(torch.long).to(self.device)
            for _ in range(fends[i][0]-1):
                memory = memory.to(self.device)
                tgt_mask = (self.generate_square_subsequent_mask(ys.size(0))
                            .type(torch.bool)).to(self.device)
                out = model.decode(ys, memory, tgt_mask)
                out = out.transpose(0, 1)
                prob = model.generator(out[:, -1])
                _, next_word = torch.max(prob, dim=1)
                next_word = next_word.item()
                ys = torch.cat([ys,
                                torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=0)
                if next_word == data_preprocess.EOS_token:
                    break

            outputs.append(ys)

        return outputs

    def string_from_X(self,decoder_outputs,type=0,is_input=False):
        strings = []
        if is_input:
            for i in decoder_outputs:
                decoded_ids = i
                decoded_words = []
                for idx in decoded_ids:
                    if idx == self.EOS_token:
                        break
                    decoded_words.append(self.in_lang.index2word[idx.item()])
                strings.append(' '.join(decoded_words))
        else:
            if type == 0:
                for i in decoder_outputs:
                    _, topi = i.topk(1)
                    decoded_ids = topi.squeeze()

                    decoded_words = []
                    for idx in decoded_ids:
                        if idx.item() == self.EOS_token:
                            break
                        decoded_words.append(self.out_lang.index2word[idx.item()])
                    strings.append(' '.join(decoded_words))
            else:
                for i in decoder_outputs:
                    decoded_ids = i
                    decoded_words = []
                    for idx in decoded_ids:
                        if idx == self.EOS_token:
                            break
                        decoded_words.append(self.out_lang.index2word[idx.item()])
                    decoded_words = decoded_words[1:]
                    strings.append(' '.join(decoded_words))

        return strings

    # actual function to translate input sentence into target language
    def translate(self, model: torch.nn.Module, sentence_batch):
        model.eval()
        masks = []
        ends = []
        sentences = []
        long_flag = False
        for i in range(sentence_batch.shape[0]):
            current_sentence = sentence_batch[i]
            end_val = (current_sentence == data_preprocess.EOS_token).nonzero(as_tuple=True)[0]
            ends.append(end_val+10)
            if end_val > 20:
                long_flag = True
            current_sentence = current_sentence[:end_val.item()]
            sentences.append(current_sentence)
            src_mask = (torch.zeros(current_sentence.shape[0],current_sentence.shape[0])).type(torch.bool)
            masks.append(src_mask)

        tgt_tokens = self.greedy_decode(
            model,  sentences, masks,ends, start_symbol=data_preprocess.SOS_token)


        strings = self.string_from_X(tgt_tokens,type=1)
        return strings,long_flag

        # for i in tgt_tokens:
        #     tens = i.flatten().tolist()
        #     string_repr = self.string_from_X(tens,type=1)
        #     print(string_repr)


    def eval(self,in_i,tgt_i):
        self.transformer.eval()
        long = False
        counter = 0
        while not long:
            choices = np.random.choice(len(in_i), 1, replace=False)
            counter += 1
            input_sentence_batch = in_i[choices]
            target_sentence_batch = tgt_i[choices]
            valid_str = input_sentence_batch[:,1:]

            input_strings = self.string_from_X(valid_str,is_input=True)
            translated_strings,long = self.translate(self.transformer,valid_str)
            target_strings = self.string_from_X(target_sentence_batch,type=1)

            for i in range(len(input_strings)):
                print("Counter =",counter)
                print("Input >",input_strings[i])
                print("Target >",target_strings[i])
                print("Translated =",translated_strings[i])
                print('\n')

# %%
config_dict = {
    "convert_eng_to_lang": False,
    "epoch_count": 20000,
    "learning_rate": 0.001,
    "max_sentence_length": 25,
    "hidden_size": 1024,
    "batch_size": 5,
    "from_lang": "fra",
    "use_pkl_data": True,
    "rnn_type": "gru",
    "loss_type": "nll",
    "optimizer": "adam",
    "use_attention": True
}
trainer = Trainer(config_dict,device)
# Out:
# {'batch_size': 5,
#  'convert_eng_to_lang': False,
#  'epoch_count': 20000,
#  'from_lang': 'fra',
#  'hidden_size': 1024,
#  'learning_rate': 0.001,
#  'loss_type': 'nll',
#  'max_sentence_length': 25,
#  'optimizer': 'adam',
#  'rnn_type': 'gru',
#  'use_attention': True,
#  'use_pkl_data': True}

# %%
trainer.eval(trainer.in_ids,trainer.tgt_ids)
# Out:
# Counter = 1
# Input > es-tu certain que c'est sur  ?
# Target > are you sure that's safe ?
# Translated = are you sure that's safe ?
#
#
# Counter = 2
# Input > quant a moi, je veux rester en vie .
# Target > i want to stay alive .
# Translated = i want to stay alive .
#
#
# Counter = 3
# Input > elle le soigna jusqu'a ce qu'il recouvre la sante .
# Target > she nursed him back to health .
# Translated = she treated her best in health .
#
#
# Counter = 4
# Input > ce livre est tres petit .
# Target > this book is very small .
# Translated = this book is very small .
#
#
# Counter = 5
# Input > tom chuchota quelque chose a l’oreille de marie .
# Target > tom whispered something into mary's ear .
# Translated = tom whispered something to mary .
#
#
# Counter = 6
# Input > il a rappele a sa femme de le reveiller a 7 heures du matin .
# Target > he reminded his wife to wake him up at 7:00 a .m .
# Translated = he reminded his wife to wake him up at seven in the morning .
#
#
# Counter = 7
# Input > tom chuchota quelque chose a l’oreille de marie .
# Target > tom whispered something into mary's ear .
# Translated = tom whispered something to mary .
#
#
# Counter = 8
# Input > je l'ai dit a la police .
# Target > i've told the police .
# Translated = i told the police .
#
#
# Counter = 9
# Input > tu as combien de sœurs  ?
# Target > how many sisters do you have ?
# Translated = how many sisters do you have ?
#
#
# Counter = 10
# Input > il planifie toujours une chose minutieusement avant de la faire .
# Target > he always plans a thing out carefully before he does it .
# Translated = he always gets a thing worked before doing it .
#
#
# Counter = 11
# Input > otez les abats du poulet avant de le cuire .
# Target > remove the chicken's giblets before cooking .
# Translated = take care of chicken before cooking .
#
#
# Counter = 12
# Input > tu dois etre amical avec tes voisins .
# Target > you must be friendly with your neighbors .
# Translated = you must be friendly with your neighbors .
#
#
# Counter = 13
# Input > y a-t-il un endroit ou l'on puisse en parler en prive  ?
# Target > is there somewhere we can talk privately about this ?
# Translated = is there a place we can talk in private ?
#
#
# Counter = 14
# Input > s'il te plait, attends encore un petit peu .
# Target > please wait a little longer .
# Translated = please wait a little bit longer .
#
#
# Counter = 15
# Input > merci . vous avez ete d'une grande aide .
# Target > thanks . you've been a big help .
# Translated = thank you for your help .
#
#
# Counter = 16
# Input > il est sorti par la fenetre .
# Target > he went out the window .
# Translated = he went out the window .
#
#
# Counter = 17
# Input > devrais-je appeler une ambulance  ?
# Target > should i call an ambulance ?
# Translated = should i call an ambulance ?
#
#
# Counter = 18
# Input > elles l'entendirent a la radio .
# Target > they heard it on the radio .
# Translated = they heard it on the radio .
#
#
# Counter = 19
# Input > y etes-vous pret  ?
# Target > are you up for it ?
# Translated = are you ready for it ?
#
#
# Counter = 20
# Input > il ne veut pas s'attirer des ennuis .
# Target > he doesn't want to get in trouble .
# Translated = he doesn't want to get in trouble .
#
#
# Counter = 21
# Input > le bug a ete corrige .
# Target > the bug has been fixed .
# Translated = the bug has been corrected .
#
#
# Counter = 22
# Input > je savais que tom etait peintre .
# Target > i knew tom was a painter .
# Translated = i knew tom was a painter .
#
#
# Counter = 23
# Input > tu ne peux pas avoir ca .
# Target > you can't have that .
# Translated = you can't have that .
#
#
# Counter = 24
# Input > sa mere est une bonne pianiste .
# Target > her mother is a good pianist .
# Translated = her mother is a good pianist .
#
#
# Counter = 25
# Input > nous sommes tellement contentes de vous avoir ici  !
# Target > we're so glad to have you here .
# Translated = we're so glad that we have you here .
#
#
# Counter = 26
# Input > l'enfant fut fait pupille de la nation .
# Target > the child was made a ward of the state .
# Translated = the child was let out of the nation .
#
#
# Counter = 27
# Input > demain, j'acheterai ce dont j'ai besoin .
# Target > tomorrow i'll buy what i need .
# Translated = i'll buy what i need .
#
#
# Counter = 28
# Input > je ne savais pas dans quoi j'etais en train de m'engager .
# Target > i didn't know what i was getting into .
# Translated = i didn't know what i was going to join .
#
#
# Counter = 29
# Input > pourquoi ne pas l'essayer  ?
# Target > why not try it on ?
# Translated = why don't you try it ?
#
#
# Counter = 30
# Input > son anglais n'est pas mauvais, sachant qu'il ne l'etudie que depuis deux ans .
# Target > his english is not bad, seeing that he has studied for only two years .
# Translated = his english isn't bad, except he eats english than two years old .
#
#
# Counter = 31
# Input > nous allons a l'ecole tous les jours, sauf le dimanche .
# Target > we go to school every day except sunday .
# Translated = we go to school every day except sunday .
#
#
# Counter = 32
# Input > connaissez-vous de bons endroits pour manger, autour d'ici  ?
# Target > do you know any good places to eat around here ?
# Translated = do you know good places to eat around here ?
#
#
# Counter = 33
# Input > elle n'avait d'autre choix que d'accepter son destin .
# Target > she had no choice but to accept her fate .
# Translated = she had no choice but to accept her fate .
#
#
# Counter = 34
# Input > ou sont vos affaires  ?
# Target > where are your things ?
# Translated = where are your things ?
#
#
# Counter = 35
# Input > qui a gagne le concours  ?
# Target > who won the contest ?
# Translated = who won the if he won ?
#
#
# Counter = 36
# Input > il accorde de l'importance a cette affaire .
# Target > he attaches importance to this matter .
# Translated = he doesn't matter how important that matter .
#
#
# Counter = 37
# Input > cette chemise est trop petite pour que je la porte .
# Target > this shirt is too small for me to wear .
# Translated = that shirt is too small for me to wear .
#
#
# Counter = 38
# Input > tom s'est decourage .
# Target > tom became discouraged .
# Translated = tom got discouraged .
#
#
# Counter = 39
# Input > pouvons-nous laisser tomber ceci  ?
# Target > can we drop this ?
# Translated = can we drop this ?
#
#
# Counter = 40
# Input > qu'est-ce qui s'est passe a l'ecole, hier  ?
# Target > what happened at school yesterday ?
# Translated = what happened at school yesterday ?
#
#
# Counter = 41
# Input > c'est juste entre toi et moi .
# Target > this is just between you and me .
# Translated = it's just between you and me .
#
#
# Counter = 42
# Input > parlons-en autour d'un verre .
# Target > let's talk about that over drinks .
# Translated = let's talk about a drink .
#
#
# Counter = 43
# Input > c'est jour pluvieux .
# Target > it's a rainy day .
# Translated = it's rainy day .
#
#
# Counter = 44
# Input > vous avez finalement reussi a trouver un emploi .
# Target > you finally succeeded in getting a job .
# Translated = you finally succeeded in finding a job .
#
#
# Counter = 45
# Input > verrouillez votre porte  !
# Target > lock your door .
# Translated = lock your door .
#
#
# Counter = 46
# Input > regardez autour de toi .
# Target > take a look around you .
# Translated = look around you .
#
#
# Counter = 47
# Input > etes-vous des environs  ?
# Target > are you from around here ?
# Translated = are you nearby ?
#
#
# Counter = 48
# Input > tom est enseignant de francais .
# Target > tom is a french teacher .
# Translated = tom is a french teacher .
#
#
# Counter = 49
# Input > je ne travaille pas souvent le lundi .
# Target > i don't often work on mondays .
# Translated = i don't often work on monday .
#
#
# Counter = 50
# Input > quel est ton jour de fete prefere  ?
# Target > what is your favorite holiday ?
# Translated = what's your favorite holiday ?
#
#
# Counter = 51
# Input > quelle equipe gagnera la partie  ?
# Target > which team will win the game ?
# Translated = what team will play the game ?
#
#
# Counter = 52
# Input > arrete d'essayer de m'embrasser .
# Target > stop trying to kiss me .
# Translated = stop trying to kiss me .
#
#
# Counter = 53
# Input > l'angleterre a etabli beaucoup de colonies .
# Target > england established many colonies .
# Translated = england set a lot of am coming .
#
#
# Counter = 54
# Input > j'aime la choucroute .
# Target > i like sauerkraut .
# Translated = i love ham .
#
#
# Counter = 55
# Input > vous savez ce qu'elles disent .
# Target > you know what they say .
# Translated = you know what they say .
#
#
# Counter = 56
# Input > tout ca fait partie du plan .
# Target > it's all part of the plan .
# Translated = that's all part of the plan .
#
#
# Counter = 57
# Input > tom et marie voulaient tous les deux beaucoup d'enfants .
# Target > tom and mary both wanted a lot of children .
# Translated = tom and mary both wanted a lot of children .
#
#
# Counter = 58
# Input > je parlerai avec toi demain .
# Target > i'll talk to you tomorrow .
# Translated = i'll speak with you tomorrow .
#
#
# Counter = 59
# Input > continuez de chanter .
# Target > keep singing .
# Translated = keep singing .
#
#
# Counter = 60
# Input > je fais une promenade avec mon chien le soir .
# Target > i take a walk with my dog in the evening .
# Translated = i take a walk with my dog tonight .
#
#
# Counter = 61
# Input > mary est en train d'etudier dans sa chambre .
# Target > mary is studying in her room .
# Translated = mary is studying in her room .
#
#
# Counter = 62
# Input > je suis conducteur .
# Target > i'm a chauffeur .
# Translated = i'm driving . i'm driving .
#
#
# Counter = 63
# Input > tout ca est un grand malentendu .
# Target > this is all a big misunderstanding .
# Translated = it's all a big misunderstanding .
#
#
# Counter = 64
# Input > je suis sur le chemin de la maison en revenant du travail .
# Target > i'm on my way home from work .
# Translated = i'm on my way home on my way home from work .
#
#
# Counter = 65
# Input > je sais que tom est un peu timide .
# Target > i know tom is a little shy .
# Translated = i know tom is a bit shy .
#
#
# Counter = 66
# Input > le policier mit l'homme en joue .
# Target > the policeman aimed his gun at the man .
# Translated = the policeman played the man played .
#
#
# Counter = 67
# Input > je savais que c'etait trop beau pour etre vrai .
# Target > i knew this was too good to be true .
# Translated = i knew it was too good to be true .
#
#
# Counter = 68
# Input > ce travail est simple au point que meme un enfant peut l'accomplir .
# Target > this work is simple enough that even a child can do it .
# Translated = this work is simple enough that even a child can do it .
#
#
# Counter = 69
# Input > elles sont allees faire du surf .
# Target > they went surfing .
# Translated = they went surfing .
#
#
# Counter = 70
# Input > nous vous souhaitons un agreable voyage .
# Target > we wish you a pleasant journey .
# Translated = we wish you a pleasant trip .
#
#
# Counter = 71
# Input > je ne vais pas m'impliquer .
# Target > i'm not getting involved .
# Translated = i won't get involved .
#
#
# Counter = 72
# Input > il a echappe a la mort de justesse .
# Target > he narrowly escaped being killed .
# Translated = he escaped death by the narrow escape .
#
#
# Counter = 73
# Input > peut-etre me suis-je trompe .
# Target > i may have been mistaken .
# Translated = maybe i was wrong .
#
#
# Counter = 74
# Input > tous les anglais n'aiment pas le poisson-pommes frites .
# Target > not all english people like fish and chips .
# Translated = not every english likes best .
#
#
# Counter = 75
# Input > faisons une pause the .
# Target > let's take a tea break .
# Translated = let's have a tea break .
#
#
# Counter = 76
# Input > montez dans la voiture, s'il vous plait .
# Target > get in the car, please .
# Translated = please get in the car .
#
#
# Counter = 77
# Input > quand je serai grand, je veux etre exactement comme vous .
# Target > when i grow up, i want to be just like you .
# Translated = when i grow up, i want to be just like you .
#
#
# Counter = 78
# Input > j'avais l'habitude de nager quotidiennement quand j'etais enfant .
# Target > i used to swim every day when i was a child .
# Translated = i used to swim every day when i was a child .
#
#
# Counter = 79
# Input > si seulement ma femme pouvait se plaindre moins .
# Target > i wish that my wife wouldn't complain so much .
# Translated = i wish my wife wouldn't complain so much .
#
#
# Counter = 80
# Input > comment t'es-tu donc arrange pour faire ca  ?
# Target > how in the world did you do such a thing ?
# Translated = how did you get fixed it ?
#
#
# Counter = 81
# Input > cela peut paraitre etrange, mais c'est neanmoins vrai .
# Target > it sounds strange, but it is true none the less .
# Translated = it may sound strange, but it is still true .
#
#
# Counter = 82
# Input > l'accident le priva de la vue .
# Target > the accident deprived him of his sight .
# Translated = the accident deprived of the sight .
#
#
# Counter = 83
# Input > je vis avec mes parents .
# Target > i live at home with my parents .
# Translated = i live with my parents .
#
#
# Counter = 84
# Input > les secours sont arrives sur place en quelques minutes .
# Target > paramedics arrived on the scene within minutes .
# Translated = rescue arrived on a few minutes .
#
#
# Counter = 85
# Input > vous avez toujours une chance .
# Target > you still have a chance .
# Translated = you're always a chance .
#
#
# Counter = 86
# Input > je suis surprise que vous ne saviez pas que tom parlait francais .
# Target > i'm surprised you didn't know tom could speak french .
# Translated = i'm surprised you didn't know tom spoke french .
#
#
# Counter = 87
# Input > c'est toi qui t'es emballee .
# Target > you're the one that went crazy .
# Translated = it's your favorite went crazy .
#
#
# Counter = 88
# Input > le president s'est adresse a la nation a la television .
# Target > the president spoke to the nation on tv .
# Translated = the president addressed the nation to tv .
#
#
# Counter = 89
# Input > elles l'ont trouve .
# Target > they found it .
# Translated = they found it .
#
#
# Counter = 90
# Input > je sais que tu ne m’aimeras jamais .
# Target > i know you'll never love me .
# Translated = i know that you never wanted me .
#
#
# Counter = 91
# Input > comment ca se prononce  ?
# Target > how is that pronounced ?
# Translated = how is it going through ?
#
#
# Counter = 92
# Input > je peux le voir dans vos yeux .
# Target > i can see it in your eyes .
# Translated = i can see it in your eyes .
#
#
# Counter = 93
# Input > ma voiture ne demarre pas .
# Target > my car won't start .
# Translated = my car won't start .
#
#
# Counter = 94
# Input > vous ne devriez pas lire avec un eclairage aussi faible .
# Target > you shouldn't read in such poor light .
# Translated = you shouldn't read an weak from this weak .
#
#
# Counter = 95
# Input > que preparez-vous  ?
# Target > what are you up to ?
# Translated = what are you preparing ?
#
#
# Counter = 96
# Input > tom a gagne le premier prix .
# Target > tom won first prize .
# Translated = tom won first prize .
#
#
# Counter = 97
# Input > je pense que nous nous sentirons tous mieux apres avoir dormi un peu .
# Target > i think we'll all feel better once we get a little sleep .
# Translated = i think we all got along after i slept a little bit .
#
#
# Counter = 98
# Input > ceux qui etaient presents a la reunion furent surpris par la nouvelle .
# Target > those present at the meeting were surprised at the news .
# Translated = those were present at the meeting were surprised by the news .
#
#
# Counter = 99
# Input > tu es nerveusement use .
# Target > you're a nervous wreck .
# Translated = you're a nervous wreck .
#
#
# Counter = 100
# Input > nous voila  !
# Target > here we are !
# Translated = here we she is !
#
#
# Counter = 101
# Input > ils te tueront .
# Target > they'll kill you .
# Translated = they'll kill you . they'll kill you .
#
#
# Counter = 102
# Input > c'est si difficile .
# Target > this is so hard .
# Translated = it's so difficult .
#
#
# Counter = 103
# Input > tu es gentille .
# Target > you're kind .
# Translated = you're nice .
#
#
# Counter = 104
# Input > que recommandez-vous  ?
# Target > what do you recommend ?
# Translated = what do you recommend ?
#
#
# Counter = 105
# Input > tom a ferme la porte de sa chambre .
# Target > tom closed the door of his bedroom .
# Translated = tom shut the bedroom door .
#
#
# Counter = 106
# Input > je pense qu'elle est innocente .
# Target > i think she's innocent .
# Translated = i think that she's innocent .
#
#
# Counter = 107
# Input > tu ferais mieux de remettre ca .
# Target > you'd better hand that over .
# Translated = you'd better put that back .
#
#
# Counter = 108
# Input > je veux mourir .
# Target > i want to die .
# Translated = i want to die . i want to die .
#
#
# Counter = 109
# Input > y allez-vous en bus ou en voiture  ?
# Target > are you going by bus or car ?
# Translated = do you go by bus or by car ?
#
#
# Counter = 110
# Input > je n'aime ni les pommes ni le raisin .
# Target > i like neither apples nor grapes .
# Translated = i like apples and grapes .
#
#
# Counter = 111
# Input > tom semble etre nerveux .
# Target > tom seems nervous .
# Translated = tom seems to be nervous .
#
#
# Counter = 112
# Input > quelle est l'activite principale de cette ville  ?
# Target > what is the main industry in this town ?
# Translated = what's the main like this city ?
#
#
# Counter = 113
# Input > peux-tu attendre un peu  ?
# Target > can you wait a bit ?
# Translated = can you wait a little ?
#
#
# Counter = 114
# Input > nous ne sommes pas des flics .
# Target > we're not cops .
# Translated = we're not cops .
#
#
# Counter = 115
# Input > je pris une mauvaise decision .
# Target > i made a bad decision .
# Translated = i made a bad decision .
#
#
# Counter = 116
# Input > tu n'es pas la seule canadienne ici .
# Target > you're not the only canadian here .
# Translated = you're not the only canadian here .
#
#
# Counter = 117
# Input > je vais voir si je peux trouver une carte .
# Target > i'll see if i can find a map .
# Translated = i'll see if i can find a map .
#
#
# Counter = 118
# Input > quel est le plus beau cadeau que tu as recu a noel dernier  ?
# Target > what was the best present you received last christmas ?
# Translated = what was the best present you got last christmas ?
#
#
# Counter = 119
# Input > ce n'est pas un jour de conge .
# Target > it isn't a holiday .
# Translated = it's not a day off .
#
#
# Counter = 120
# Input > qu'ont-ils pris  ?
# Target > what did they take ?
# Translated = would you take it ?
#
#
# Counter = 121
# Input > je n'ai pas encore pris de decision .
# Target > i haven't decided yet .
# Translated = i haven't made a decision yet .
#
#
# Counter = 122
# Input > j'avais raison depuis le debut .
# Target > i was right all along .
# Translated = i had the beginning .
#
#
# Counter = 123
# Input > la bougie s'est consumee .
# Target > the candle burned out .
# Translated = the candle got out .
#
#
# Counter = 124
# Input > que faites-vous pour arreter cela  ?
# Target > what are you doing to stop this ?
# Translated = what do you do that for stop ?
#
#
# Counter = 125
# Input > j'ai peur des chiens .
# Target > i'm scared of dogs .
# Translated = i'm afraid of dogs .
#
#
# Counter = 126
# Input > tout est tres cher dans ce magasin .
# Target > everything is very expensive in this store .
# Translated = everything is very expensive in this store .
#
#
# Counter = 127
# Input > vous voulez quelque chose de moi, n'est-ce pas  ?
# Target > you want something from me, don't you ?
# Translated = you want something from me, don't you ?
#
#
# Counter = 128
# Input > je ne vois pas ce qui est si amusant .
# Target > i fail to see what's so amusing .
# Translated = i don't see what's so funny .
#
#
# Counter = 129
# Input > il me faut y aller seule .
# Target > i must go alone .
# Translated = i have to go alone .
#
#
# Counter = 130
# Input > tom ne peut pas nager aussi vite que mary .
# Target > tom can't swim as fast as mary .
# Translated = tom can't swim as fast as mary can .
#
#
# Counter = 131
# Input > je n'ai aucune raison d'apprendre cette langue .
# Target > i have no reason to learn that language .
# Translated = i have no reason to learn this language .
#
#
# Counter = 132
# Input > « sans crochets, comment as-tu fait pour t’introduire  ? » « la fenetre de la toilette etait ouverte . »
# Target > "with no picks how did you break in ?" "the toilet window was open ."
# Translated = let's nobody how did you turn to the toilet ?" "the toilet was open ."
#
#
# Counter = 133
# Input > j'ai fait tout ce que j'ai pu pour sauver tom .
# Target > i did everything i could to save tom .
# Translated = i did everything i could to save tom .
#
#
# Counter = 134
# Input > je le savais depuis longtemps .
# Target > i'd known that for a long time .
# Translated = i knew that a long time .
#
#
# Counter = 135
# Input > pourrais-tu, s'il te plait, te depecher  ?
# Target > could you please hurry ?
# Translated = could you have a few things ?
#
#
# Counter = 136
# Input > ce n'est pas de ta faute .
# Target > that isn't your fault .
# Translated = it's not your fault .
#
#
# Counter = 137
# Input > combien de temps a dure le match  ?
# Target > how long did the game last ?
# Translated = how long did the game last game ?
#
#
# Counter = 138
# Input > laquelle est ta tasse  ?
# Target > which cup is yours ?
# Translated = which cup is yours ?
#
#
# Counter = 139
# Input > seul un idiot ferait une chose pareille .
# Target > only a fool would do something like that .
# Translated = only a fool would do such a thing .
#
#
# Counter = 140
# Input > nous devons faire face a des problemes difficiles .
# Target > we have some difficult problems that we need to deal with .
# Translated = we have to deal with difficult problems .
#
#
# Counter = 141
# Input > il a l'air de se mefier de nous .
# Target > he seems to be wary of us .
# Translated = it looks like we're suspicious of us .
#
#
# Counter = 142
# Input > qui est cette mignonne fille avec laquelle je t'ai vu a la galerie commerciale  ?
# Target > who's that cute girl i saw you with at the mall ?
# Translated = who's that cute girl i saw you with at the mall ?
#
#
# Counter = 143
# Input > il posa quelques questions a la dame qui se tenait pres de lui .
# Target > he asked the lady standing next to him some questions .
# Translated = he asked some questions of the lady standing next to him .
#
#
# Counter = 144
# Input > elle a decide de ne pas y aller .
# Target > she decided not to go .
# Translated = she decided not to go .
#
#
# Counter = 145
# Input > ne te laisse pas abuser par les apparences  !
# Target > don't be fooled by appearances .
# Translated = don't be fooled by looks .
#
#
# Counter = 146
# Input > il me faut te parler .
# Target > i've got to talk to you .
# Translated = i must talk to you .
#
#
# Counter = 147
# Input > je l'ai convaincu d'abandonner l'idee .
# Target > i persuaded him to give up the idea .
# Translated = i persuaded him to give up the idea .
#
#
# Counter = 148
# Input > m’approuve-t-on  ?
# Target > am i approved ?
# Translated = are you coming ?
#
#
# Counter = 149
# Input > j'aimerais quelques pommes de terre .
# Target > i want some potatoes .
# Translated = i'd like some potatoes .
#
#
# Counter = 150
# Input > parlez a vos amies .
# Target > talk to your friends .
# Translated = talk to your friends .
#
#
# Counter = 151
# Input > ca ne me derange pas de vous aider a nettoyer apres la fete .
# Target > i don't mind helping you clean up after the party .
# Translated = i don't mind helping you clean after the party .
#
#
# Counter = 152
# Input > oh, ne sois pas si modeste  !
# Target > oh, don't be so modest .
# Translated = oh, don't be so modest .
#
#
# Counter = 153
# Input > tom s'est mis a marmonner .
# Target > tom started mumbling .
# Translated = tom started .
#
#
# Counter = 154
# Input > tu es tres jolie aujourd'hui .
# Target > you look very pretty today .
# Translated = you're very pretty today .
#
#
# Counter = 155
# Input > vous avez l'air tres fatiguee .
# Target > you look very tired .
# Translated = you look very tired .
#
#
# Counter = 156
# Input > le velo est un sport agreable .
# Target > cycling is a great sport .
# Translated = the bicycle is a pleasant sport .
#
#
# Counter = 157
# Input > les manteaux noirs sont a la mode cet hiver .
# Target > black coats are in fashion this winter .
# Translated = black collect fashion .
#
#
# Counter = 158
# Input > nous tentons notre chance .
# Target > we're tempting fate .
# Translated = we're trying our chance .
#
#
# Counter = 159
# Input > elles annoncerent qu'elles avaient une maison a vendre .
# Target > they advertised that they had a house for sale .
# Translated = they advertised that they had a house for sale .
#
#
# Counter = 160
# Input > j'entends tom qui chante .
# Target > i can hear tom singing .
# Translated = i hear who singing .
#
#
# Counter = 161
# Input > il etait seul .
# Target > he was alone .
# Translated = he was alone .
#
#
# Counter = 162
# Input > il y a une pointe de rouge dans le ciel oriental .
# Target > there is a tinge of red in the eastern sky .
# Translated = there is a point of red stone into the sky .
#
#
# Counter = 163
# Input > je dors debout .
# Target > i sleep standing up .
# Translated = i'm getting up .
#
#
# Counter = 164
# Input > je suppose que c'est tout ce que j'ai besoin de savoir .
# Target > i guess that's all i need to know .
# Translated = i suppose that's all i need to know .
#
#
# Counter = 165
# Input > je pense qu'il est temps pour moi de faire l'acquisition d'un nouvel appareil photo .
# Target > i think it's time for me to buy a new camera .
# Translated = i think it's time for me to buy a new camera .
#
#
# Counter = 166
# Input > il a ete mon premier petit ami .
# Target > he was my first boyfriend .
# Translated = he was my first boyfriend .
#
#
# Counter = 167
# Input > la saison des pluies debute en juin .
# Target > rainy season begins in june .
# Translated = the rainy season begins in june .
#
#
# Counter = 168
# Input > veux-tu savoir ou tu t'es trompe  ?
# Target > do you want to know where you made your mistake ?
# Translated = do you want to know where you've been wrong ?
#
#
# Counter = 169
# Input > je ne savais pas que vous connaissiez tom .
# Target > i didn't know you knew tom .
# Translated = i didn't know you knew tom .
#
#
# Counter = 170
# Input > on s'en est occupe .
# Target > it's been taken care of .
# Translated = we're busy .
#
#
# Counter = 171
# Input > tom etait sobre .
# Target > tom was sober .
# Translated = tom was sober .
#
#
# Counter = 172
# Input > il y a un musee juste au nord du zoo .
# Target > there is a museum just north of the zoo .
# Translated = there's a museum just north america .
#
#
# Counter = 173
# Input > personne ne veut jouer aux echecs avec moi .
# Target > nobody wants to play chess with me .
# Translated = no one wants to play chess with me .
#
#
# Counter = 174
# Input > j'aimerais parler a votre gerant .
# Target > i'd like to speak to your manager .
# Translated = i'd like to talk to your manager .
#
#
# Counter = 175
# Input > le silence sinistre a fait trembler leurs cœurs .
# Target > the eerie silence struck terror into their hearts .
# Translated = silence missed their feeling quiet .
#
#
# Counter = 176
# Input > tu aimes noel, n'est-ce pas  ?
# Target > you love christmas, don't you ?
# Translated = you love christmas, don't you ?
#
#
# Counter = 177
# Input > j'ai toujours deteste la biologie .
# Target > i've always hated biology .
# Translated = i've always hated biology .
#
#
# Counter = 178
# Input > je ne suis pas assez bien pour tom .
# Target > i'm not good enough for tom .
# Translated = i'm not good enough for tom .
#
#
# Counter = 179
# Input > elles auraient pu vous tuer .
# Target > they could've killed you .
# Translated = they could've killed you .
#
#
# Counter = 180
# Input > puis-je en avoir un  ?
# Target > can i have one of these ?
# Translated = can i have one ?
#
#
# Counter = 181
# Input > ce comedien est tres drole .
# Target > that comedian is very funny .
# Translated = this time, it's very funny .
#
#
# Counter = 182
# Input > je ne pouvais pas dire a tom ce qui allait se passer .
# Target > i couldn't tell tom what was going to happen .
# Translated = i couldn't tell tom what was going to happen .
#
#
# Counter = 183
# Input > arretez de siffler, je vous prie  !
# Target > please stop whistling .
# Translated = please stop whistling .
#
#
# Counter = 184
# Input > je suis persuade qu'il viendra a temps .
# Target > i'm sure that he'll come on time .
# Translated = i'm sure that he'll come to time .
#
#
# Counter = 185
# Input > le gouvernement a explicitement annonce son intention de baisser les impots .
# Target > the government explicitly declared its intention to lower taxes .
# Translated = the government rain saved down his taxes .
#
#
# Counter = 186
# Input > ne dis rien aux autres, d'accord  ?
# Target > don't tell the others, ok ?
# Translated = don't tell the others ok ?
#
#
# Counter = 187
# Input > elle l'a surpris par un baiser .
# Target > she surprised him with a kiss .
# Translated = she caught him by a kiss .
#
#
# Counter = 188
# Input > regarde ce batiment .
# Target > look at that building .
# Translated = look at that building .
#
#
# Counter = 189
# Input > je n'ai jamais pense que ca finirait comme ca .
# Target > i never thought it would wind up like this .
# Translated = i never thought it would happen like that .
#
#
# Counter = 190
# Input > tu devrais demander conseil a ton pere et t'y tenir .
# Target > you should ask your father for his advice and follow it .
# Translated = you should ask your father and there are going to .
#
#
# Counter = 191
# Input > prenez des notes .
# Target > take notes .
# Translated = get notes .
#
#
# Counter = 192
# Input > j'ai prepare a diner .
# Target > i cooked dinner .
# Translated = i made dinner .
#
#
# Counter = 193
# Input > ils ne te rendent pas heureux .
# Target > they don't make you happy .
# Translated = they're not happy .
#
#
# Counter = 194
# Input > nous devons reduire le cout a un minimum .
# Target > we have to reduce the cost to a minimum .
# Translated = we need to reduce cost a drink .
#
#
# Counter = 195
# Input > je dois me mettre sur mon trente-et-un .
# Target > i have to dress up .
# Translated = i have to wear my let's being on my let's dangerous .
#
#
# Counter = 196
# Input > leurs problemes financiers ont commence au deuxieme semestre .
# Target > their financial problems began in the second half of the year .
# Translated = their financial problems began to the second semester .
#
#
# Counter = 197
# Input > j'aime vraiment le basketball .
# Target > i really like basketball .
# Translated = i really like basketball .
#
#
# Counter = 198
# Input > il n'a jamais revu son frere .
# Target > he never saw his brother again .
# Translated = he never saw his brother again .
#
#
# Counter = 199
# Input > ouvre la bouteille .
# Target > open the bottle .
# Translated = open the bottle .
#
#
# Counter = 200
# Input > habillez-vous .
# Target > get dressed .
# Translated = dress dress quickly . get dressed .
#
#
# Counter = 201
# Input > aucun d'entre nous ne connaissait la reponse .
# Target > none of us knew the answer .
# Translated = none of us knew the answer .
#
#
# Counter = 202
# Input > promets-moi que tu seras prudent  !
# Target > promise me you'll be careful .
# Translated = promise me you'll be careful .
#
#
# Counter = 203
# Input > tom s'est assis entre nous .
# Target > tom sat between us .
# Translated = tom sat in .
#
#
# Counter = 204
# Input > c'etait plutot bien, non  ?
# Target > that was rather good, wasn't it ?
# Translated = it was pretty well, wasn't it ?
#
#
# Counter = 205
# Input > les avez-vous envoyees  ?
# Target > did you send them ?
# Translated = did you send them ?
#
#
# Counter = 206
# Input > c'est le nord qui a vaincu lors de la bataille de shiloh .
# Target > the north won the battle of shiloh .
# Translated = the north defeated the battle of the well battle .
#
#
# Counter = 207
# Input > comment cela peut-il etre possible  ?
# Target > how can this be possible ?
# Translated = how can that be possible ?
#
#
# Counter = 208
# Input > je n'ai pas regarde la tele hier .
# Target > i didn't watch television yesterday .
# Translated = i didn't watch tv yesterday .
#
#
# Counter = 209
# Input > je vais jouer au tennis demain .
# Target > i'm going to play tennis tomorrow .
# Translated = i'm going to play tennis tomorrow .
#
#
# Counter = 210
# Input > c'est comme vous le dites .
# Target > it's as you say .
# Translated = that's how you're telling .
#
#
# Counter = 211
# Input > une amitie etroite nous lie .
# Target > we are bound to each other by a close friendship .
# Translated = a narrow friendship is bound .
#
#
# Counter = 212
# Input > il parlait avec une douceur caracteristique des sudistes .
# Target > he spoke with a softness characteristic of southerners .
# Translated = he spoke with a foreign of an ever winter .
#
#
# Counter = 213
# Input > j'ai besoin de vous dans ma vie .
# Target > i need you in my life .
# Translated = i need you in my life .
#
#
# Counter = 214
# Input > et si le plan ne fonctionne pas  ?
# Target > what if the scheme doesn't work out ?
# Translated = what if the plan doesn't work ?
#
#
# Counter = 215
# Input > tom a un beau jardin .
# Target > tom has a beautiful garden .
# Translated = tom has a beautiful garden .
#
#
# Counter = 216
# Input > vous pouvez toujours compter sur lui en cas d'urgence .
# Target > you can always count on him in any emergency .
# Translated = you can always count on him in case of an emergency .
#
#
# Counter = 217
# Input > cela ne me semble pas stupide .
# Target > that doesn't sound stupid to me .
# Translated = that doesn't seem stupid to me .
#
#
# Counter = 218
# Input > un detenu s'est echappe de prison .
# Target > a convict has escaped from prison .
# Translated = a life escaped from prison .
#
#
# Counter = 219
# Input > je pense que tom va venir plus tard .
# Target > i think that tom will be coming later .
# Translated = i think tom will come later .
#
#
# Counter = 220
# Input > l'arbre a ete frappe par la foudre .
# Target > the tree was struck by lightning .
# Translated = the tree was struck by lightning .
#
#
# Counter = 221
# Input > c'etait un cas de confusion d'identite .
# Target > it was a case of mistaken identity .
# Translated = i used to take my i appreciate .
#
#
# Counter = 222
# Input > pourquoi etes-vous si anxieuse  ?
# Target > why are you so insecure ?
# Translated = why are you so insecure ?
#
#
# Counter = 223
# Input > je n'ai pas fait ca .
# Target > i didn't do that .
# Translated = i didn't do that .
#
#
# Counter = 224
# Input > j'aimerais la note, je vous prie .
# Target > check, please .
# Translated = i'd like the bill, please .
#
#
# Counter = 225
# Input > je viens de petit-dejeuner .
# Target > i've just finished eating breakfast .
# Translated = i just had breakfast .
#
#
# Counter = 226
# Input > tu as des freres et sœurs  ?
# Target > do you have any brothers or sisters ?
# Translated = do you have any brothers and sisters ?
#
#
# Counter = 227
# Input > tom s'est prepare une boisson .
# Target > tom made himself a drink .
# Translated = tom made a drink .
#
#
# Counter = 228
# Input > que ferez-vous si vous ne trouvez pas assez de nourriture pour nourrir votre famille  ?
# Target > what'll you do if you can't find enough food to feed your family ?
# Translated = what will you do if you don't get enough food to feed your family ?
#
#
# Counter = 229
# Input > tom voulait etre un musicien professionnel .
# Target > tom wanted to be a professional musician .
# Translated = tom wanted to be a professional musician .
#
#
# Counter = 230
# Input > j'aimerais un peu plus d'eau .
# Target > i'd like a little more water .
# Translated = i'd like a little more water .
#
#
# Counter = 231
# Input > j'ai environ le meme age que vous .
# Target > i'm about the same age as you .
# Translated = i'm about the same age as you are .
#
#
# Counter = 232
# Input > je ne peux rien vous promettre .
# Target > i can't make you any promises .
# Translated = i can't promise you anything .
#
#
# Counter = 233
# Input > je suis desolee de ne pas avoir pu vous aider .
# Target > i'm sorry i couldn't help you .
# Translated = i'm sorry that i couldn't help you .
#
#
# Counter = 234
# Input > j'ai mal a l'estomac .
# Target > i have a stomachache .
# Translated = my stomach hurts .
#
#
# Counter = 235
# Input > ne manger que des fruits et legumes t'aide-t-il a perdre du poids  ?
# Target > can eating just vegetables help you lose weight ?
# Translated = just eat some fruit and help you lose weight ?
#
#
# Counter = 236
# Input > vous avez franchi la ligne .
# Target > you crossed the line .
# Translated = you crossed the line .
#
#
# Counter = 237
# Input > il faut l'etouffer dans l'œuf .
# Target > this needs to be nipped in the bud .
# Translated = we have to we're several egg .
#
#
# Counter = 238
# Input > regarde cette montagne .
# Target > look at that mountain .
# Translated = look at that mountain .
#
#
# Counter = 239
# Input > mon pere etait deja a la maison quand je suis rentre .
# Target > my father was already at home when i came back .
# Translated = my father has already been home when i got home .
#
#
# Counter = 240
# Input > vous ne pouvez plus le repousser .
# Target > you can't put off doing that any longer .
# Translated = you can't postpone the going to .
#
#
# Counter = 241
# Input > j'attends le dejeuner .
# Target > i'm waiting for lunch .
# Translated = i'm waiting for lunch .
#
#
# Counter = 242
# Input > je veux m'assurer que tu vas bien aller .
# Target > i want to make sure you're going to be all right .
# Translated = i want to make sure you're going to be all right .
#
#
# Counter = 243
# Input > tom a donne sa demission .
# Target > tom's resigned .
# Translated = tom gave his resignation .
#
#
# Counter = 244
# Input > que vous a offert tom  ?
# Target > what did tom offer you ?
# Translated = what did tom offer you ?
#
#
# Counter = 245
# Input > je viens d'acheter un bateau .
# Target > i just bought a boat .
# Translated = i just bought a boat .
#
#
# Counter = 246
# Input > je savais que c'etait tom .
# Target > i knew it was tom .
# Translated = i knew it was tom .
#
#
# Counter = 247
# Input > n'importe quoi pouvait arriver .
# Target > anything could happen .
# Translated = anything could happen .
#
#
# Counter = 248
# Input > comment t'en es-tu donc sorti  ?
# Target > how did you ever get out of it ?
# Translated = how did you get out of yourself ?
#
#
# Counter = 249
# Input > nous sommes a court de munitions .
# Target > we're out of ammo .
# Translated = we've run out of ammunition .
#
#
# Counter = 250
# Input > ca me donne une idee .
# Target > this gives me an idea .
# Translated = that gives me an idea .
#
#
# Counter = 251
# Input > tout est pret .
# Target > everything is ready .
# Translated = everything is ready .
#
#
# Counter = 252
# Input > ca a ete une chouette fete .
# Target > it was a nice party .
# Translated = it was a nice party .
#
#
# Counter = 253
# Input > je pense qu'il est temps pour moi d'acheter une nouvelle voiture .
# Target > i think it's time for me to buy a new car .
# Translated = i think it's time for me to buy a new car .
#
#
# Counter = 254
# Input > elle n'est pas celle pour toi .
# Target > it's not the right one for you .
# Translated = she's not the one for you .
#
#
# Counter = 255
# Input > tenez votre chambre aussi nette que vous pouvez .
# Target > keep your room as neat as you can .
# Translated = keep your room as neat as you can .
#
#
# Counter = 256
# Input > puis-je vous demander qui vous etes  ?
# Target > may i ask who you are ?
# Translated = can i ask who you are ?
#
#
# Counter = 257
# Input > elle vit au milieu de nulle part .
# Target > she is living in the middle of nowhere .
# Translated = she lives in the middle of nowhere .
#
#
# Counter = 258
# Input > mettez le balai dans le placard .
# Target > put the broom in the closet .
# Translated = put the broom in the closet .
#
#
# Counter = 259
# Input > je suis heureux que vous veniez .
# Target > i'm glad you're coming .
# Translated = i'm glad you're coming .
#
#
# Counter = 260
# Input > quel est le mot magique  ?
# Target > what's the magic word ?
# Translated = what's the magic word ?
#
#
# Counter = 261
# Input > tom ne veut pas habiter a boston .
# Target > tom doesn't want to live in boston .
# Translated = tom doesn't want to live in boston .
#
#
# Counter = 262
# Input > la reunion etait pour ainsi dire close .
# Target > the meeting was just about over .
# Translated = the meeting was all but closed .
#
#
# Counter = 263
# Input > je me suis entretenu de cette affaire avec lui .
# Target > i spoke with him about the matter .
# Translated = i talked to the matter with him .
#
#
# Counter = 264
# Input > on est sortis ensemble pendant trois mois .
# Target > we dated for three months .
# Translated = we went out together for three months .
#
#
# Counter = 265
# Input > je suis alle en italie pour la seconde fois en 1980 .
# Target > i went to italy for the second time in 1980 .
# Translated = i went to italy for the second time in everything in about that .
#
#
# Counter = 266
# Input > tom est un sorcier et marie est une sorciere .
# Target > tom is a warlock and mary is a witch .
# Translated = tom is a make a around and mary is a to think .
#
#
# Counter = 267
# Input > le garcon a colle son visage contre la vitrine .
# Target > the boy pressed his face against the shop window .
# Translated = the boy landed his face against the window .
#
#
# Counter = 268
# Input > il y a un besoin urgent d'argent .
# Target > there is an urgent need for money .
# Translated = there is an urgent need for money .
#
#
# Counter = 269
# Input > vous ai-je entendues parler a quelqu'un  ?
# Target > did i hear you talking to someone ?
# Translated = did i hear you talking to someone ?
#
#
# Counter = 270
# Input > mes parents sont morts dans un accident de voiture .
# Target > my parents died in a car accident .
# Translated = my parents died in a car accident .
#
#
# Counter = 271
# Input > maman, pouvez-vous me lire une histoire au lit  ?
# Target > mom, could you read me a bedtime story ?
# Translated = hey, can you read a story to bed ?
#
#
# Counter = 272
# Input > il s'etait fait des ennemis au cours du debut de sa vie politique .
# Target > he had made enemies during his early political life .
# Translated = he had enemies at the beginning of his life together .
#
#
# Counter = 273
# Input > a quelle heure part le premier train  ?
# Target > what time does the first train leave ?
# Translated = what time does the first train leave ?
#
#
# Counter = 274
# Input > n'etait-il pas suppose neiger, la nuit derniere  ?
# Target > wasn't it supposed to snow last night ?
# Translated = wasn't it supposed to snow last night ?
#
#
# Counter = 275
# Input > ne me derange pas quand j'etudie .
# Target > don't disturb me while i'm studying .
# Translated = don't mind while i study .
#
#
# Counter = 276
# Input > n'est-ce pas mignon  ?
# Target > isn't it cute ?
# Translated = isn't it cute ?
#
#
# Counter = 277
# Input > as-tu besoin d'aide  ?
# Target > do you need help ?
# Translated = are you in need of help ?
#
#
# Counter = 278
# Input > cette conversation est enregistree .
# Target > this conversation is being recorded .
# Translated = this conversation is other .
#
#
# Counter = 279
# Input > il a traduit homere du grec a l'anglais .
# Target > he translated homer from the greek into english .
# Translated = he translated greek greek to english .
#
#
# Counter = 280
# Input > je pense que vous allez vouloir vous asseoir .
# Target > i think you're going to want to sit down .
# Translated = i think you're going to want to sit down .
#
#
# Counter = 281
# Input > connaissez-vous qui que ce soit qui se trouvait sur ce vaisseau qui a coule  ?
# Target > do you know anyone who was on that ship that sunk ?
# Translated = do you know anyone who was on that ship that sunk ?
#
#
# Counter = 282
# Input > je pensais que ca t'interesserait .
# Target > i thought you'd be interested in this .
# Translated = i thought you'd be interested in this .
#
#
# Counter = 283
# Input > tom est son vrai prenom, n'est-ce pas  ?
# Target > tom is his real name, isn't it ?
# Translated = tom is his real things didn't he ?
#
#
# Counter = 284
# Input > quand avez-vous appris a faire des pizzas  ?
# Target > when did you learn to make pizza ?
# Translated = when did you learn to make pizza ?
#
#
# Counter = 285
# Input > j'etais fort reticent .
# Target > i was very reluctant .
# Translated = i was very reluctant .
#
#
# Counter = 286
# Input > je travaille sur sa voiture .
# Target > i'm working on his car .
# Translated = i work on his car .
#
#
# Counter = 287
# Input > nous devons faire quelque chose pour empecher ceci de se reproduire .
# Target > we have to do something to stop this from happening again .
# Translated = we have to make something to prevent this from happening .
#
#
# Counter = 288
# Input > tom etait seul dans sa chambre .
# Target > tom was alone in his room .
# Translated = tom was alone in his bedroom .
#
#
# Counter = 289
# Input > je suis contente que vous ayez appele .
# Target > i'm glad you called .
# Translated = i'm glad you called .
#
#
# Counter = 290
# Input > les amants echangerent de nombreuses lettres .
# Target > the lovers exchanged numerous letters .
# Translated = the lovers exchanged many letters .
#
#
# Counter = 291
# Input > nous avons beaucoup de points en commun .
# Target > we have a lot in common .
# Translated = we have a lot of points in common .
#
#
# Counter = 292
# Input > j'ai essaye d'oublier .
# Target > i tried to forget .
# Translated = i try to forget . i try it .
#
#
# Counter = 293
# Input > si vous aviez gare votre voiture ici, vous auriez eu une amende .
# Target > if you'd parked your car here, you'd have been fined .
# Translated = if you had parked your car here, you would have been fined .
#
#
# Counter = 294
# Input > mon passe-temps est la collection de pieces anciennes .
# Target > my hobby is collecting old coins .
# Translated = my hobby is collecting ancient coins .
#
#
# Counter = 295
# Input > je ne m'attendais pas a ca .
# Target > i wasn't expecting that .
# Translated = i didn't expect this .
#
#
# Counter = 296
# Input > tu n'es pas occupe maintenant, si  ?
# Target > you aren't busy now, are you ?
# Translated = you're not busy now, are you ?
#
#
# Counter = 297
# Input > personne ne pouvait se rappeler de la succession des evenements .
# Target > nobody could remember the sequence of events .
# Translated = no one could remember the coming events .
#
#
# Counter = 298
# Input > j'esperais plus .
# Target > i was hoping for more .
# Translated = i was hoping more .
#
#
# Counter = 299
# Input > c'est illegal de garer votre voiture ici .
# Target > it's illegal to park your car here .
# Translated = it's illegal to park here .
#
#
# Counter = 300
# Input > pars  !
# Target > go away !
# Translated = get away !
#
#
# Counter = 301
# Input > tu vas aimer ce cours de musique .
# Target > you're going to like this music class .
# Translated = you'll like this music class .
#
#
# Counter = 302
# Input > tom croit que mary a ete tuee .
# Target > tom believes mary was murdered .
# Translated = tom believes mary was killed .
#
#
# Counter = 303
# Input > halte au feu  !
# Target > hold fire .
# Translated = stop at the fire !
#
#
# Counter = 304
# Input > il n'y avait plus de place .
# Target > there were no seats left .
# Translated = there were no room anymore .
#
#
# Counter = 305
# Input > nous pouvons peut-etre reparer ceci .
# Target > maybe we can fix this .
# Translated = perhaps we can fix this .
#
#
# Counter = 306
# Input > il y eut des questions inattendues .
# Target > there were some unexpected questions .
# Translated = there were unexpected questions .
#
#
# Counter = 307
# Input > exercez-vous un chantage a mon egard  ?
# Target > are you blackmailing me ?
# Translated = are you making me with me ?
#
#
# Counter = 308
# Input > je n'ai jamais doute de l'issue .
# Target > i never doubted the outcome .
# Translated = i never doubt after .
#
#
# Counter = 309
# Input > le gateau devrait etre bientot pret .
# Target > the cake should be done soon .
# Translated = the cake should be ready soon .
#
#
# Counter = 310
# Input > devons-nous prendre le bus  ?
# Target > do we have to take the bus ?
# Translated = do we have to take the bus ?
#
#
# Counter = 311
# Input > il allait a la peche .
# Target > he went fishing .
# Translated = he was going fishing .
#
#
# Counter = 312
# Input > il atteignit son but .
# Target > he attained his goal .
# Translated = he reached his goal .
#
#
# Counter = 313
# Input > j'ai travaille dans une ferme quand j'etais plus jeune .
# Target > i worked on a farm when i was younger .
# Translated = i worked on a farm when i was younger .
#
#
# Counter = 314
# Input > pourquoi ne demandes-tu pas simplement de l'argent a tes parents  ?
# Target > why don't you just ask your parents for money ?
# Translated = why don't you just ask your parents for money ?
#
#
# Counter = 315
# Input > je veux le mien .
# Target > i want mine .
# Translated = i want mine .
#
#
# Counter = 316
# Input > je recherche un boulot bien paye .
# Target > i'm looking for a job that pays well .
# Translated = i'm looking for a good job .
#
#
# Counter = 317
# Input > personne ne vient avec moi .
# Target > no one is coming with me .
# Translated = no one comes with me .
#
#
# Counter = 318
# Input > le visiteur s'assit en face de moi .
# Target > the visitor sat across from me .
# Translated = the it sat in front of me .
#
#
# Counter = 319
# Input > c’est a mon pere .
# Target > this is my father's .
# Translated = that's my father .
#
#
# Counter = 320
# Input > peut-etre etes-vous encore en veine .
# Target > you may still be in luck .
# Translated = you're still in luck .
#
#
# Counter = 321
# Input > qu'as-tu vu  ?
# Target > what did you see ?
# Translated = what did you see ?
#
#
# Counter = 322
# Input > je n'aurais jamais devine .
# Target > i never would've guessed .
# Translated = i would never have guessed .
#
#
# Counter = 323
# Input > il me l'a dit .
# Target > he told me about it .
# Translated = he told me .
#
#
# Counter = 324
# Input > il a fait un tour d'europe .
# Target > he made a tour of europe .
# Translated = he went to europe .
#
#
# Counter = 325
# ...
# Translated = there are many water in deal .
#
#
# Counter = 555
# Input > tu sembles etre d'une humeur massacrante, aujourd'hui .
# Target > you seem to be in such a nasty mood today .
# Translated = you seem to be in a boston today .
#
#
# Counter = 556
# Input > pouvez-vous me dire ce que vous essayez de faire  ?
# Target > can you tell me what you're trying to do ?
# Translated = can you tell me what you're trying to do ?
#
#
# Counter = 557
# Input > personne ne vit ici .
# Target > no one lives here .
# Translated = no one lives here .
#
#
# Counter = 558
# Input > il a tout nie .
# Target > he denied everything .
# Translated = he denied everything .
#
#
# Counter = 559
# Input > je suis alle a l'aeroport pour accueillir mon pere .
# Target > i went to the airport to meet my father .
# Translated = i went to the airport in my father .
#
#
# Counter = 560
# Input > tom pouvait tout faire lui-meme .
# Target > tom could do everything by himself .
# Translated = tom could do everything himself .
#
#
# Counter = 561
# Input > j'ai deja dit oui .
# Target > i've already said yes .
# Translated = i've already said yes .
#
#
# Counter = 562
# Input > appelez la police .
# Target > phone the police .
# Translated = call the police .
#
#
# Counter = 563
# Input > tom ne mache pas ses mots .
# Target > tom doesn't mince words .
# Translated = tom doesn't chew with his words .
#
#
# Counter = 564
# Input > je ne peux pas imaginer que ce soit vrai .
# Target > i can't imagine that's true .
# Translated = i can't imagine that it's true .
#
#
# Counter = 565
# Input > nous prenons l'ascendant .
# Target > we're taking over .
# Translated = we're getting short .
#
#
# Counter = 566
# Input > vous n'etes plus les bienvenus ici .
# Target > you are no longer welcome here .
# Translated = you're not welcome here anymore .
#
#
# Counter = 567
# Input > aujourd'hui je ne patinerai pas .
# Target > i'm not going to skate today .
# Translated = today won't be kept .
#
#
# Counter = 568
# Input > tom a ete cite a comparaitre .
# Target > tom was subpoenaed .
# Translated = tom has been served .
#
#
# Counter = 569
# Input > il faut l'etouffer dans l'œuf .
# Target > this needs to be nipped in the bud .
# Translated = we have to we're several egg .
#
#
# Counter = 570
# Input > ne resiste pas  !
# Target > don't resist .
# Translated = don't resist .
#
#
# Counter = 571
# Input > me vois-tu  ?
# Target > do you see me ?
# Translated = do you see me ?
#
#
# Counter = 572
# Input > c'est le stylo que j'ai perdu hier .
# Target > this is the pen that i lost yesterday .
# Translated = this is the pen i lost yesterday .
#
#
# Counter = 573
# Input > etais-tu vraiment en colere  ?
# Target > were you really angry ?
# Translated = were you really angry ?
#
#
# Counter = 574
# Input > parlez un peu plus lentement, s'il vous plait .
# Target > please speak a bit more slowly .
# Translated = please speak more slowly .
#
#
# Counter = 575
# Input > je fais partie de la chorale .
# Target > i'm a member of the glee club .
# Translated = i'm in the choir .
#
#
# Counter = 576
# Input > signe juste ici .
# Target > just sign here .
# Translated = just sign here .
#
#
# Counter = 577
# Input > il m'a donne une pomme .
# Target > he gave me an apple .
# Translated = he gave me an apple .
#
#
# Counter = 578
# Input > devine ce que j'ai trouve sur la plage .
# Target > guess what i found on the beach .
# Translated = guess what i found on the beach .
#
#
# Counter = 579
# Input > tom m’a traitee d’idiote .
# Target > tom called me stupid .
# Translated = tom called me an idiot .
#
#
# Counter = 580
# Input > mais qu'est-ce que tu fais la  ?
# Target > what are you doing here ?
# Translated = what do you do here ?
#
#
# Counter = 581
# Input > le pere de tom a quitte sa famille .
# Target > tom's father left his family .
# Translated = tom's father left his family .
#
#
# Counter = 582
# Input > je ne me suis jamais attendu a ce qu'elle nous rejoigne .
# Target > i never expected that she would join us .
# Translated = i've never waited for what she join us .
#
#
# Counter = 583
# Input > je commence a le regretter .
# Target > i'm beginning to regret it .
# Translated = i'm beginning to regret this .
#
#
# Counter = 584
# Input > la porte est reparee par le serrurier .
# Target > the door was repaired by a locksmith .
# Translated = the door is repaired by the any time .
#
#
# Counter = 585
# Input > je me rappelle avoir fait ca avec toi une fois .
# Target > i remember doing that with you once .
# Translated = i remember doing that with you once .
#
#
# Counter = 586
# Input > pourquoi etes-vous si maladroite  ?
# Target > why are you so clumsy ?
# Translated = why are you so awkward ?
#
#
# Counter = 587
# Input > tom a appele mary la nuit derniere et l'a encouragee a rejoindre l'equipe .
# Target > tom called mary last night and encouraged her to join the team .
# Translated = tom called mary the last night and encouraged her to join the team .
#
#
# Counter = 588
# Input > tom ne voulait pas devenir architecte comme son pere .
# Target > tom didn't want to become an architect like his dad .
# Translated = tom didn't want to become an architect like his father .
#
#
# Counter = 589
# Input > j'aurais du recevoir cette promotion .
# Target > i should've gotten that promotion .
# Translated = i should've received that promotion .
#
#
# Counter = 590
# Input > je n'aurais pas du boire autant de biere la nuit derniere .
# Target > i shouldn't have drunk so much beer last night .
# Translated = i shouldn't have drunk so much beer last night .
#
#
# Counter = 591
# Input > ca me donne envie de dormir d'ecouter de la musique douce .
# Target > i feel sleepy when i listen to soft music .
# Translated = it makes me want to sleep fresh music .
#
#
# Counter = 592
# Input > combien de poissons peux-tu conserver dans ton reservoir  ?
# Target > how many fish can you keep in your tank ?
# Translated = how many fish can you keep in your nothing ?
#
#
# Counter = 593
# Input > elle s'est figee en voyant la grosse araignee .
# Target > she froze at the sight of the big spider .
# Translated = she froze to see the big spider .
#
#
# Counter = 594
# Input > pourquoi vous dites cela  ?
# Target > why do you say that ?
# Translated = why are you saying that ?
#
#
# Counter = 595
# Input > je n'aime pas la facon qu'il a de te regarder .
# Target > i don't like the way he looks at you .
# Translated = i don't like the way he looks at you .
#
#
# Counter = 596
# Input > je suis heureuse que vous l'ayez apprecie .
# Target > i'm glad you liked it .
# Translated = i'm glad you liked it .
#
#
# Counter = 597
# Input > l'alarme incendie se mit a sonner .
# Target > the fire alarm sounded .
# Translated = the fire alarm began to ring .
#
#
# Counter = 598
# Input > t'es chiant .
# Target > you're annoying .
# Translated = you're boring .
#
#
# Counter = 599
# Input > tom a l'air decide .
# Target > tom looks determined .
# Translated = tom looks decided .
#
#
# Counter = 600
# Input > je crains de vous avoir offense .
# Target > i'm afraid i've offended you .
# Translated = i'm afraid i've offended you .
#
#
# Counter = 601
# Input > personne ne vous juge .
# Target > no one's judging you .
# Translated = no one is following you .
#
#
# Counter = 602
# Input > tom est drole .
# Target > tom's funny .
# Translated = tom is funny .
#
#
# Counter = 603
# Input > je sais que tom est actif .
# Target > i know tom is active .
# Translated = i know tom is active .
#
#
# Counter = 604
# Input > je suis ambidextre .
# Target > i'm ambidextrous .
# Translated = i'm go .
#
#
# Counter = 605
# Input > c'est un sale boulot et je ne veux pas le faire .
# Target > that's a filthy job and i don't want to do it .
# Translated = it's a dirty job and i don't want to do that .
#
#
# Counter = 606
# Input > il est preferable d'avoir approximativement raison que completement tort .
# Target > it's better to be approximately right than completely wrong .
# Translated = it's best to call about it is that that's all wrong .
#
#
# Counter = 607
# Input > nous organisons pour tom une fete d'anniversaire .
# Target > we are giving tom a birthday party .
# Translated = we're giving tom a birthday party .
#
#
# Counter = 608
# Input > quel est le plus grand edifice du japon  ?
# Target > what is the tallest building in japan ?
# Translated = what is the tallest building in japan ?
#
#
# Counter = 609
# Input > j'espere que tu seras mon ami .
# Target > i hope you'll be my friend .
# Translated = i hope you'll be my friend .
#
#
# Counter = 610
# Input > comment prevoyez-vous de payer ca  ?
# Target > how do you plan on paying for that ?
# Translated = how do you plan to pay for that ?
#
#
# Counter = 611
# Input > la loi a ete modifiee .
# Target > the law was changed .
# Translated = the law has been changed .
#
#
# Counter = 612
# Input > que croyiez-vous que j'allais proposer  ?
# Target > what did you think i was going to suggest ?
# Translated = what did you think i would get out ?
#
#
# Counter = 613
# Input > la pauvrete regne partout .
# Target > poverty is everywhere .
# Translated = poverty comes everywhere .
#
#
# Counter = 614
# Input > je suis bien ici .
# Target > i'm comfortable here .
# Translated = i'm pretty here .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> trainer.eval(trainer.in_ids,trainer.tgt_ids)
#
# /home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb Cell 6 line 1
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=165'>166</a> valid_str = input_sentence_batch[:,1:]
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=167'>168</a> input_strings = self.string_from_X(valid_str,is_input=True)
# --> <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=168'>169</a> translated_strings,long = self.translate(self.transformer,valid_str)
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=169'>170</a> target_strings = self.string_from_X(target_sentence_batch,type=1)
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=171'>172</a> for i in range(len(input_strings)):
#
# /home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb Cell 6 line 1
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=140'>141</a>     src_mask = (torch.zeros(current_sentence.shape[0],current_sentence.shape[0])).type(torch.bool)
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=141'>142</a>     masks.append(src_mask)
# --> <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=143'>144</a> tgt_tokens = self.greedy_decode(
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=144'>145</a>     model,  sentences, masks,ends, start_symbol=data_preprocess.SOS_token)
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=147'>148</a> strings = self.string_from_X(tgt_tokens,type=1)
#     <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=148'>149</a> return strings,long_flag
#
# /home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb Cell 6 line 7
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=72'>73</a> memory = memory.to(self.device)
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=73'>74</a> tgt_mask = (self.generate_square_subsequent_mask(ys.size(0))
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=74'>75</a>             .type(torch.bool)).to(self.device)
# ---> <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=75'>76</a> out = model.decode(ys, memory, tgt_mask)
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=76'>77</a> out = out.transpose(0, 1)
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=77'>78</a> prob = model.generator(out[:, -1])
#
# /home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb Cell 6 line 7
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=72'>73</a> def decode(self, tgt: Tensor, memory: Tensor, tgt_mask: Tensor):
# ---> <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=73'>74</a>     return self.transformer.decoder(self.positional_encoding(
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=74'>75</a>                       self.tgt_tok_emb(tgt)), memory,
#      <a href='vscode-notebook-cell:/home/caluckal/Developer/course/676/cse676_grp9/transformers/tf_eval.ipynb#W5sZmlsZQ%3D%3D?line=75'>76</a>                       tgt_mask)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/transformer.py:460, in TransformerDecoder.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, tgt_is_causal, memory_is_causal)
#     457 tgt_is_causal = _detect_is_causal_mask(tgt_mask, tgt_is_causal, seq_len)
#     459 for mod in self.layers:
# --> 460     output = mod(output, memory, tgt_mask=tgt_mask,
#     461                  memory_mask=memory_mask,
#     462                  tgt_key_padding_mask=tgt_key_padding_mask,
#     463                  memory_key_padding_mask=memory_key_padding_mask,
#     464                  tgt_is_causal=tgt_is_causal,
#     465                  memory_is_causal=memory_is_causal)
#     467 if self.norm is not None:
#     468     output = self.norm(output)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1517     else:
#    1518         return self._call_impl(*args, **kwargs)
# -> 1520 def _call_impl(self, *args, **kwargs):
#    1521     forward_call = (self._slow_forward if torch._C._get_tracing_state() else self.forward)
#    1522     # If we don't have any hooks, we want to skip the rest of the logic in
#    1523     # this function, and just call forward.
#
# KeyboardInterrupt:
